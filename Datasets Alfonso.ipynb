# %% [markdown]
# DataSets - Alberto Alfonso
#
# A continuacion se importarán los 3 datasets seleccionados para la entrega, siendo el DataSet de Ventas_Seguros con el que me interesaría trabajar en mi proyecto

# %% [markdown]
# DataSet Empleo_Amba
#
# Este DataSet muestra niveles de empleo para el área del AMBA (CABA + Conurbano PBA), asumiendo una imagen a 2022.
# Teniendo en cuentas los datos, lo que potencialmente me interesaría analizar es la división entre el empleo de CABA y el de PBA, analizar la diferencia entre el nivel de empleo de hombres y mujeres (cantidad) y las diferencias remunerativas (cualitativo). Otra cuestión es considerar el nivel de empleo teniendo en cuenta a la población y por último realizar estos análisis antes descriptos de acuerdo a la edad y a partir de todo eso analizar la evolucion de las remuneraciones, los niveles de empleo y las edades para 2023.

# %%
import pandas as pd
Empleo_Amba= pd.read_csv('data/Empleo-AMBA-sin-desagregar.csv',sep=';', on_bad_lines='skip')
Empleo_Amba
# Out:
#        provincia_id  departamento_id  Cantidad_trabajadores  \
# 0                 2             2007                    334
# 1                 2             2007                    564
# 2                 2             2007                    198
# 3                 2             2007                    228
# 4                 2             2007                    267
# ...             ...              ...                    ...
# 13877             6             6861                     76
# 13878             6             6861                     83
# 13879             6             6861                    132
# 13880             6             6861                    151
# 13881             6             6861                    122
#
#        Cantidad_trabajadores_Hombres  Cantidad_trabajadores_Mujeres  \
# 0                                187                          147.0
# 1                                304                          260.0
# ...

# %% [markdown]
# DataSet Ventas_Seguros
#
# Este DataSet muestra las ventas de una compañía de seguros entre 2020 y 2022 inclusive.
# Teniendo en cuenta que ésta es la industria para la cual trabajo, me interesaría componer mi proyecto con este dataset.
# Aqui lo interesante no sería solo la cantidad de ventas, sino los diferentes productos que se venden (Producto), a que ramo pertenecen (Rama), a que personas se le hacen las ventas (Tomadores, Tipos de personas), cuantas personas se aseguran por póliza (Asegurados por poliza), las radicaciones de las personas (Domicilio).
# Lo que me interesa es poder establecer un panorama de ventas para 2023 en general, y en particular para cada una de las cuestiones que menciono en el párrafo anterior.

# %%
Ventas_Seguros= pd.read_csv('data/ventas2020-2022.csv',sep=';', on_bad_lines='skip')
Ventas_Seguros
# Out:
#        PRODUCTO  OPERACIÓN  CODIGO TOMADOR  \
# 0             1         17              41
# 1             1         18              41
# 2             1         19              41
# 3             2         15              41
# 4             2         16              41
# ...         ...        ...             ...
# 89139       304         21          236152
# 89140       304         24          214399
# 89141       304         33          307443
# 89142       304         35          139212
# 89143       304         38           89931
#
#                                     NOMBRE TOMADOR  CODIGO DE PRODUCTOR  \
# 0      SMSV INSTITUCION MUTUALISTA | 2030527516737                    1
# 1      SMSV INSTITUCION MUTUALISTA | 2030527516737                    1
# 2      SMSV INSTITUCION MUTUALISTA | 2030527516737                    1
# 3      SMSV INSTITUCION MUTUALISTA | 2030527516737                    1
# 4      SMSV INSTITUCION MUTUALISTA | 2030527516737                    1
# ...

# %% [markdown]
# DataSet Dengue
#
# Este DataSet muestra los contagios de Dengue en el país en 2019, 2020 y 2021.
# Las variables que me interesaría analizar son la distribución de la enfermedad en el país, la cantidad de contagios, pero también particularmente los rangos etarios afectados y el desenvolvimiento de la enfermedad, o sea cuantas personas fueron internadas y fallecidas por este tema.

# %%
Dengue= pd.read_csv('data/Dengue 2019-2021.csv',sep=';', on_bad_lines='skip')
Dengue
# Out:
#       departamento_id  provincia_id provincia_nombre   ano  \
# 0                2001             2             CABA  2019
# 1                2001             2             CABA  2019
# 2                2001             2             CABA  2019
# 3                2001             2             CABA  2019
# 4                2010             2             CABA  2019
# ...               ...           ...              ...   ...
# 13459           90084            90          Tucuman  2021
# 13460           90084            90          Tucuman  2021
# 13461           90105            90          Tucuman  2021
# 13462           90084            90          Tucuman  2021
# 13463           90084            90          Tucuman  2021
#
#        semanas_epidemiologicas evento_nombre grupo_edad_id  \
# 0                            3        Dengue             6
# 1                            7        Dengue             6
# 2                            7        Dengue             8
# ...
